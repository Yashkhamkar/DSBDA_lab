# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/Data_DSBDA/Heart.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
#seaborn barplot
sns.barplot(x='ChestPain' ,y='Chol', data=df)
# Out:
# <Axes: xlabel='ChestPain', ylabel='Chol'>

# %%
#scatterplot seaborn
sns.scatterplot(x='Age',y='MaxHR',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='MaxHR'>

# %%
#lineplot seaborn
sns.lineplot(x='Age',y='MaxHR',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='MaxHR'>

# %%
#pairPlot Seaborn
plt.figure(figsize=(12,12))
sns.pairplot(df,hue='Sex', palette='Blues')

# %%
#displot sns
sns.displot(df['Sex'])

# %%
##1)scatter
plt.scatter(df['Sex'],df['Age'])

# %%
#2)Barplot
plt.bar(df['Sex'],df['Age'])
# Out:
# <BarContainer object of 303 artists>

# %%
#3)Pie chart
sex_df=pd.DataFrame(df['Sex'].value_counts())
sex_df
# Out:
#    Sex
# 1  206
# 0   97

# %%
plt.pie(sex_df['Sex'], labels=sex_df.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff1d3e70e80>,
# ...
#  [Text(-0.5890242258008583, 0.9290050922463771, '1'),
#   Text(0.5890242258008579, -0.9290050922463774, '0')])
